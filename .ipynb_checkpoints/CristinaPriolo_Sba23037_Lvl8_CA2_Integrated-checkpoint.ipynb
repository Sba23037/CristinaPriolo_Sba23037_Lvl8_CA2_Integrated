# %% [markdown]
# # DATA PREPARATION:

# %%
import pandas as pd
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
dataset= pd.read_csv("Employee_Attrition.csv")

# %%
dataset.shape
# Out:
# (1470, 35)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1323 non-null   float64
#  1   Attrition                 1323 non-null   object
#  2   BusinessTravel            1323 non-null   object
#  3   DailyRate                 1323 non-null   float64
#  4   Department                1323 non-null   object
#  5   DistanceFromHome          1323 non-null   float64
#  6   Education                 1323 non-null   float64
#  7   EducationField            1323 non-null   object
#  8   EmployeeCount             1323 non-null   float64
#  9   EmployeeNumber            1323 non-null   float64
#  10  EnvironmentSatisfaction   1323 non-null   float64
#  11  Gender                    1323 non-null   object
#  12  HourlyRate                1323 non-null   float64
#  13  JobInvolvement            1323 non-null   float64
#  14  JobLevel                  1323 non-null   float64
#  15  JobRole                   1323 non-null   object
#  16  JobSatisfaction           1323 non-null   float64
#  17  MaritalStatus             1323 non-null   object
#  18  MonthlyIncome             1323 non-null   float64
#  19  MonthlyRate               1323 non-null   float64
#  20  NumCompaniesWorked        1323 non-null   float64
#  21  Over18                    1323 non-null   object
#  22  OverTime                  1323 non-null   object
#  23  PercentSalaryHike         1323 non-null   float64
#  24  PerformanceRating         1323 non-null   float64
#  25  RelationshipSatisfaction  1323 non-null   float64
#  26  StandardHours             1323 non-null   float64
#  27  StockOptionLevel          1323 non-null   float64
#  28  TotalWorkingYears         1323 non-null   float64
#  29  TrainingTimesLastYear     1323 non-null   float64
#  30  WorkLifeBalance           1323 non-null   float64
#  31  YearsAtCompany            1323 non-null   float64
#  32  YearsInCurrentRole        1323 non-null   float64
#  33  YearsSinceLastPromotion   1323 non-null   float64
#  34  YearsWithCurrManager      1323 non-null   float64
# dtypes: float64(26), object(9)
# memory usage: 402.1+ KB

# %%
print("The data set has {} rows and {} columns".format(dataset.shape[0], dataset.shape[1]))
display(dataset.describe())
display(dataset.head())
display(dataset.dtypes.value_counts())
# Out:
# The data set has 1470 rows and 35 columns
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1323.000000  1323.000000       1323.000000  1323.000000    1323.000000
# mean     36.635268   802.030050          9.091097     2.923447       0.999325
# std       9.882161   414.031025          8.177870     1.072203       0.099656
# min      14.544608    86.828045          0.750112     0.770362       0.628985
# 25%      29.624982   456.479553          2.147069     2.122706       0.931146
# 50%      34.951950   782.958705          6.920808     3.015658       0.998949
# 75%      42.748741  1130.577949         13.584900     3.700560       1.067371
# max      69.402515  1784.394456         33.684424     6.285161       1.290613
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1323.000000              1323.000000  1323.000000     1323.000000
# mean      1026.679166                 2.726443    65.647722        2.743028
# std        610.480802                 1.129679    21.469709        0.765568
# min          1.054148                 0.759655    23.855272        0.722008
# 25%        501.854842                 1.894818    47.701897        2.177638
# 50%       1022.025017                 2.887313    64.934490        2.859143
# 75%       1533.811096                 3.676600    83.038355        3.179128
# max       2530.919375                 5.254672   123.200439        5.241968
#
#           JobLevel  ...  RelationshipSatisfaction  StandardHours  \
# count  1323.000000  ...               1323.000000    1323.000000
# mean      2.058270  ...                  2.720431      80.241313
# std       1.127018  ...                  1.115959       8.022535
# min       0.715172  ...                  0.720696      53.793059
# 25%       1.045228  ...                  1.909010      74.882946
# 50%       1.936150  ...                  2.891235      80.351400
# 75%       2.609707  ...                  3.639961      85.664169
# max       5.942269  ...                  5.092280     107.378705
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count       1323.000000        1323.000000            1323.000000
# mean           0.814757          11.426152               2.811756
# std            0.863076           8.075870               1.329044
# min            0.000000           0.000000               0.000000
# 25%            0.000000           5.953221               1.967328
# 50%            0.913651           9.306742               2.690934
# 75%            1.082523          15.324548               3.366949
# max            3.474319          47.641892               7.503201
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      1323.000000     1323.000000         1323.000000
# mean          2.762825        6.933624            4.233363
# std           0.761802        6.046798            3.658111
# min           0.799138        0.000000            0.000000
# 25%           2.193390        2.673269            1.824392
# 50%           2.899807        5.422160            2.968874
# 75%           3.206117        9.238005            7.052591
# max           4.856086       36.848408           19.091844
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count              1323.000000           1323.000000
# mean                  2.160710              4.117695
# std                   3.221481              3.594053
# min                   0.000000              0.000000
# 25%                   0.000000              1.687177
# 50%                   0.967140              2.939240
# 75%                   2.586631              6.987964
# max                  17.273662             19.976003
#
# [8 rows x 26 columns]
#          Age Attrition     BusinessTravel    DailyRate  \
# 0  41.920786       Yes      Travel_Rarely   990.110009
# 1  51.589037        No  Travel_Frequently   276.776030
# 2  33.131540       Yes      Travel_Rarely  1204.158501
# 3  34.707073        No  Travel_Frequently  1352.752432
# 4  24.790188        No      Travel_Rarely   485.053333
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales          1.016716   1.770313  Life Sciences
# 1  Research & Development               NaN   1.035333  Life Sciences
# 2  Research & Development          2.198662   2.118801          Other
# 3                   Sales          2.937851   3.670674  Life Sciences
# 4  Research & Development          1.988953   1.120496        Medical
#
#    EmployeeCount  EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0       1.033298        1.054148  ...                  1.012832     95.612654
# 1       0.944859        2.107031  ...                  4.312008     85.370868
# 2       0.810809        4.008125  ...                  2.332558     76.248084
# 3       0.822976        4.587269  ...                  3.029591     75.888697
# 4            NaN        7.228740  ...                       NaN     72.670937
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 0          0.000000           8.063833               0.000000        1.052104
# 1          1.104642           8.965059               3.264952        2.526470
# 2          0.000000           8.427238               3.004521        2.924784
# 3          0.000000           7.662606               2.856001        3.117053
# 4          0.953012           6.241733               2.814719        3.112317
#
#    YearsAtCompany YearsInCurrentRole  YearsSinceLastPromotion  \
# 0        5.795945           3.993896                 0.000000
# 1       10.070232           7.937505                 1.032295
# 2        0.000000           0.000000                 0.000000
# 3        8.435324           5.563667                 2.845429
# 4        2.040124           1.970786                 2.495949
#
#    YearsWithCurrManager
# 0              4.594972
# 1              5.901207
# 2              0.000000
# 3              0.000000
# 4              2.219353
#
# [5 rows x 35 columns]
# float64    26
# object      9
# Name: count, dtype: int64

# %% [markdown]
# It is noticable that the dataset has 1470 observationd and 35 features. Also with the function .info() the dataset shos the present of float and object but no integer and it is noticable thta some of the variable needs to be transformed like for example the Age and more of the variable needs to be transformed in integers after the missing variable will be handled

# %% [markdown]
# Check for duplicates:

# %%
dataset.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Missing values:

# %%
dataset.isnull().sum()
# Out:
# Age                         147
# Attrition                   147
# BusinessTravel              147
# DailyRate                   147
# Department                  147
# DistanceFromHome            147
# Education                   147
# EducationField              147
# EmployeeCount               147
# EmployeeNumber              147
# EnvironmentSatisfaction     147
# Gender                      147
# HourlyRate                  147
# JobInvolvement              147
# JobLevel                    147
# JobRole                     147
# JobSatisfaction             147
# MaritalStatus               147
# MonthlyIncome               147
# MonthlyRate                 147
# NumCompaniesWorked          147
# Over18                      147
# OverTime                    147
# PercentSalaryHike           147
# PerformanceRating           147
# RelationshipSatisfaction    147
# StandardHours               147
# StockOptionLevel            147
# TotalWorkingYears           147
# TrainingTimesLastYear       147
# WorkLifeBalance             147
# YearsAtCompany              147
# YearsInCurrentRole          147
# YearsSinceLastPromotion     147
# YearsWithCurrManager        147
# dtype: int64

# %%
missing_values = dataset.isnull().sum()
total_values = dataset.shape[0]

percentage_missing = (missing_values / total_values) * 100

print(percentage_missing)
# Out:
# Age                         10.0
# Attrition                   10.0
# BusinessTravel              10.0
# DailyRate                   10.0
# Department                  10.0
# DistanceFromHome            10.0
# Education                   10.0
# EducationField              10.0
# EmployeeCount               10.0
# EmployeeNumber              10.0
# EnvironmentSatisfaction     10.0
# Gender                      10.0
# HourlyRate                  10.0
# JobInvolvement              10.0
# JobLevel                    10.0
# JobRole                     10.0
# JobSatisfaction             10.0
# MaritalStatus               10.0
# MonthlyIncome               10.0
# MonthlyRate                 10.0
# NumCompaniesWorked          10.0
# Over18                      10.0
# OverTime                    10.0
# PercentSalaryHike           10.0
# PerformanceRating           10.0
# RelationshipSatisfaction    10.0
# StandardHours               10.0
# StockOptionLevel            10.0
# TotalWorkingYears           10.0
# TrainingTimesLastYear       10.0
# WorkLifeBalance             10.0
# YearsAtCompany              10.0
# YearsInCurrentRole          10.0
# YearsSinceLastPromotion     10.0
# YearsWithCurrManager        10.0
# dtype: float64

# %% [markdown]
# We can notice that the 10% of each features have missing variable. his is a valid point because it means that we canot drop the missing value due that the dataset will bbe left with really low observation

# %%
dataset.isnull().sum().sum()
# Out:
# 5145

# %% [markdown]
# total of missing variable are 5145

# %% [markdown]
# # Visualization of missing values:

# %%
pip install missingno
# Out:
# Requirement already satisfied: missingno in c:\users\cristinap\appdata\local\anaconda3\lib\site-packages (0.5.2)
# Requirement already satisfied: numpy in c:\users\cristinap\appdata\local\anaconda3\lib\site-packages (from missingno) (1.24.3)
# Requirement already satisfied: matplotlib in c:\users\cristinap\appdata\local\anaconda3\lib\site-packages (from missingno) (3.7.3)
# Requirement already satisfied: scipy in c:\users\cristinap\appdata\local\anaconda3\lib\site-packages (from missingno) (1.11.1)
# Requirement already satisfied: seaborn in c:\users\cristinap\appdata\local\anaconda3\lib\site-packages (from missingno) (0.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cristinap\appdata\local\anaconda3\lib\site-packages (from matplotlib->missingno) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\cristinap\appdata\local\anaconda3\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cristinap\appdata\local\anaconda3\lib\site-packages (from matplotlib->missingno) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\cristinap\appdata\local\anaconda3\lib\site-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\cristinap\appdata\local\anaconda3\lib\site-packages (from matplotlib->missingno) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\cristinap\appdata\local\anaconda3\lib\site-packages (from matplotlib->missingno) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\cristinap\appdata\local\anaconda3\lib\site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cristinap\appdata\local\anaconda3\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\cristinap\appdata\local\anaconda3\lib\site-packages (from seaborn->missingno) (2.0.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cristinap\appdata\local\anaconda3\lib\site-packages (from pandas>=0.25->seaborn->missingno) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\cristinap\appdata\local\anaconda3\lib\site-packages (from pandas>=0.25->seaborn->missingno) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\cristinap\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import missingno as msno

ax = msno.matrix(dataset.sample(500))

# %%
ax = msno.heatmap(dataset, figsize=(20, 20))

# %%
ax = msno.dendrogram(dataset)

# %% [markdown]
# # Visualization before handling missing variables and encoding:

# %%
pd.set_option('display.max_columns', None)
print(dataset.head())
# Out:
#          Age Attrition     BusinessTravel    DailyRate  \
# 0  41.920786       Yes      Travel_Rarely   990.110009
# 1  51.589037        No  Travel_Frequently   276.776030
# 2  33.131540       Yes      Travel_Rarely  1204.158501
# 3  34.707073        No  Travel_Frequently  1352.752432
# 4  24.790188        No      Travel_Rarely   485.053333
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales          1.016716   1.770313  Life Sciences
# 1  Research & Development               NaN   1.035333  Life Sciences
# 2  Research & Development          2.198662   2.118801          Other
# 3                   Sales          2.937851   3.670674  Life Sciences
# 4  Research & Development          1.988953   1.120496        Medical
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0       1.033298        1.054148                 2.146294    Male   93.827486
# 1       0.944859        2.107031                 3.470803    Male   52.304157
# 2       0.810809        4.008125                 3.979420    Male   87.271332
# 3       0.822976        4.587269                 3.734705  Female   56.378982
# 4            NaN        7.228740                 1.079412    Male   40.433887
#
#    JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# 0        3.426960  2.464492        Sales Executive         3.397665
# 1        1.813458  1.788697     Research Scientist         1.584059
# 2        1.877226  0.833488  Laboratory Technician         3.301009
# 3        2.932646  1.095372     Research Scientist         3.220844
# 4        3.117739  0.937746  Laboratory Technician         1.697330
#
#   MaritalStatus  MonthlyIncome   MonthlyRate  NumCompaniesWorked Over18  \
# 0        Single    6438.949336  20845.103714            7.077818      Y
# 1       Married    4457.659622  24877.898697            1.114423      Y
# 2        Single    2124.545220   2262.942954            5.539591      Y
# 3       Married    2771.699080  27189.905714            0.772793    NaN
# 4       Married    3254.601575  17675.541599           10.118125    NaN
#
#   OverTime  PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 0      Yes           9.898765           2.844897                  1.012832
# 1       No                NaN           4.120281                  4.312008
# 2      Yes          15.401596           2.781168                  2.332558
# 3      Yes           9.757546           2.769576                  3.029591
# 4      NaN          11.920147           3.282183                       NaN
#
#    StandardHours  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0      95.612654          0.000000           8.063833               0.000000
# 1      85.370868          1.104642           8.965059               3.264952
# 2      76.248084          0.000000           8.427238               3.004521
# 3      75.888697          0.000000           7.662606               2.856001
# 4      72.670937          0.953012           6.241733               2.814719
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0         1.052104        5.795945            3.993896
# 1         2.526470       10.070232            7.937505
# 2         2.924784        0.000000            0.000000
# 3         3.117053        8.435324            5.563667
# 4         3.112317        2.040124            1.970786
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                 0.000000              4.594972
# 1                 1.032295              5.901207
# 2                 0.000000              0.000000
# 3                 2.845429              0.000000
# 4                 2.495949              2.219353

# %%
import matplotlib.pyplot as plt
department_counts = dataset['Department'].value_counts()

plt.figure(figsize=(8, 6))
department_counts.plot(kind='bar', color='skyblue')
plt.title('Distribution of Employees by Department')
plt.xlabel('Department')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=dataset, y='JobRole', palette='viridis')
plt.title('Distribution of Employees by Job Role')
plt.xlabel('Count')
plt.ylabel('Job Role')
plt.tight_layout()
plt.show()

# %%
education_field_counts = dataset['EducationField'].value_counts()

plt.figure(figsize=(10, 6))
plt.pie(education_field_counts, labels=education_field_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Education Fields')
plt.axis('equal') 
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=dataset, x='MaritalStatus', hue='Gender', palette='Set2')
plt.title('Distribution of Employees by Marital Status and Gender')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.legend(title='Gender')
plt.tight_layout()
plt.show()

# %%
education_field_counts = dataset['Attrition'].value_counts()

plt.figure(figsize=(10, 6))
plt.pie(education_field_counts, labels=education_field_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution if Employee left or not the company')
plt.axis('equal') 
plt.tight_layout()
plt.show()

# %% [markdown]
# # Handling missing datas

# %%
missing_values=["NA","N/A","-","NaN","missing","na","?"]

# %%
dataset.head()
# Out:
#          Age Attrition     BusinessTravel    DailyRate  \
# 0  41.920786       Yes      Travel_Rarely   990.110009
# 1  51.589037        No  Travel_Frequently   276.776030
# 2  33.131540       Yes      Travel_Rarely  1204.158501
# 3  34.707073        No  Travel_Frequently  1352.752432
# 4  24.790188        No      Travel_Rarely   485.053333
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales          1.016716   1.770313  Life Sciences
# 1  Research & Development               NaN   1.035333  Life Sciences
# 2  Research & Development          2.198662   2.118801          Other
# 3                   Sales          2.937851   3.670674  Life Sciences
# 4  Research & Development          1.988953   1.120496        Medical
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0       1.033298        1.054148                 2.146294    Male   93.827486
# 1       0.944859        2.107031                 3.470803    Male   52.304157
# 2       0.810809        4.008125                 3.979420    Male   87.271332
# 3       0.822976        4.587269                 3.734705  Female   56.378982
# 4            NaN        7.228740                 1.079412    Male   40.433887
#
#    JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# 0        3.426960  2.464492        Sales Executive         3.397665
# 1        1.813458  1.788697     Research Scientist         1.584059
# 2        1.877226  0.833488  Laboratory Technician         3.301009
# 3        2.932646  1.095372     Research Scientist         3.220844
# 4        3.117739  0.937746  Laboratory Technician         1.697330
#
#   MaritalStatus  MonthlyIncome   MonthlyRate  NumCompaniesWorked Over18  \
# 0        Single    6438.949336  20845.103714            7.077818      Y
# 1       Married    4457.659622  24877.898697            1.114423      Y
# 2        Single    2124.545220   2262.942954            5.539591      Y
# 3       Married    2771.699080  27189.905714            0.772793    NaN
# 4       Married    3254.601575  17675.541599           10.118125    NaN
#
#   OverTime  PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 0      Yes           9.898765           2.844897                  1.012832
# 1       No                NaN           4.120281                  4.312008
# 2      Yes          15.401596           2.781168                  2.332558
# 3      Yes           9.757546           2.769576                  3.029591
# 4      NaN          11.920147           3.282183                       NaN
#
#    StandardHours  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0      95.612654          0.000000           8.063833               0.000000
# 1      85.370868          1.104642           8.965059               3.264952
# 2      76.248084          0.000000           8.427238               3.004521
# 3      75.888697          0.000000           7.662606               2.856001
# 4      72.670937          0.953012           6.241733               2.814719
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0         1.052104        5.795945            3.993896
# 1         2.526470       10.070232            7.937505
# 2         2.924784        0.000000            0.000000
# 3         3.117053        8.435324            5.563667
# 4         3.112317        2.040124            1.970786
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                 0.000000              4.594972
# 1                 1.032295              5.901207
# 2                 0.000000              0.000000
# 3                 2.845429              0.000000
# 4                 2.495949              2.219353

# %%
pd.set_option('display.max_columns', None)
print(dataset.head())
# Out:
#          Age Attrition     BusinessTravel    DailyRate  \
# 0  41.920786       Yes      Travel_Rarely   990.110009
# 1  51.589037        No  Travel_Frequently   276.776030
# 2  33.131540       Yes      Travel_Rarely  1204.158501
# 3  34.707073        No  Travel_Frequently  1352.752432
# 4  24.790188        No      Travel_Rarely   485.053333
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales          1.016716   1.770313  Life Sciences
# 1  Research & Development               NaN   1.035333  Life Sciences
# 2  Research & Development          2.198662   2.118801          Other
# 3                   Sales          2.937851   3.670674  Life Sciences
# 4  Research & Development          1.988953   1.120496        Medical
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0       1.033298        1.054148                 2.146294    Male   93.827486
# 1       0.944859        2.107031                 3.470803    Male   52.304157
# 2       0.810809        4.008125                 3.979420    Male   87.271332
# 3       0.822976        4.587269                 3.734705  Female   56.378982
# 4            NaN        7.228740                 1.079412    Male   40.433887
#
#    JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# 0        3.426960  2.464492        Sales Executive         3.397665
# 1        1.813458  1.788697     Research Scientist         1.584059
# 2        1.877226  0.833488  Laboratory Technician         3.301009
# 3        2.932646  1.095372     Research Scientist         3.220844
# 4        3.117739  0.937746  Laboratory Technician         1.697330
#
#   MaritalStatus  MonthlyIncome   MonthlyRate  NumCompaniesWorked Over18  \
# 0        Single    6438.949336  20845.103714            7.077818      Y
# 1       Married    4457.659622  24877.898697            1.114423      Y
# 2        Single    2124.545220   2262.942954            5.539591      Y
# 3       Married    2771.699080  27189.905714            0.772793    NaN
# 4       Married    3254.601575  17675.541599           10.118125    NaN
#
#   OverTime  PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 0      Yes           9.898765           2.844897                  1.012832
# 1       No                NaN           4.120281                  4.312008
# 2      Yes          15.401596           2.781168                  2.332558
# 3      Yes           9.757546           2.769576                  3.029591
# 4      NaN          11.920147           3.282183                       NaN
#
#    StandardHours  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0      95.612654          0.000000           8.063833               0.000000
# 1      85.370868          1.104642           8.965059               3.264952
# 2      76.248084          0.000000           8.427238               3.004521
# 3      75.888697          0.000000           7.662606               2.856001
# 4      72.670937          0.953012           6.241733               2.814719
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0         1.052104        5.795945            3.993896
# 1         2.526470       10.070232            7.937505
# 2         2.924784        0.000000            0.000000
# 3         3.117053        8.435324            5.563667
# 4         3.112317        2.040124            1.970786
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                 0.000000              4.594972
# 1                 1.032295              5.901207
# 2                 0.000000              0.000000
# 3                 2.845429              0.000000
# 4                 2.495949              2.219353

# %% [markdown]
# # Encoding:

# %% [markdown]
# I notice that over18 don't have variance, so it is not considered for the next step that is Encoding the categorical variable into numerical with LabelENcoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
cn1 = list(dataset['Attrition'].values)
le.fit(list(set(cn1)))
num_cn1 = list(le.transform(cn1))
dataset['Attrition'] = num_cn1

le = LabelEncoder()
cn1 = list(dataset['BusinessTravel'].values)
le.fit(list(set(cn1)))
num_cn1 = list(le.transform(cn1))
dataset['BusinessTravel'] = num_cn1

le = LabelEncoder()
cn1 = list(dataset['EducationField'].values)
le.fit(list(set(cn1)))
num_cn1 = list(le.transform(cn1))
dataset['EducationField'] = num_cn1

le = LabelEncoder()
cn1 = list(dataset['JobRole'].values)
le.fit(list(set(cn1)))
num_cn1 = list(le.transform(cn1))
dataset['JobRole'] = num_cn1

le = LabelEncoder()
cn1 = list(dataset['Department'].values)
le.fit(list(set(cn1)))
num_cn1 = list(le.transform(cn1))
dataset['Department'] = num_cn1

le = LabelEncoder()
cn1 = list(dataset['Gender'].values)
le.fit(list(set(cn1)))
num_cn1 = list(le.transform(cn1))
dataset['Gender'] = num_cn1

le = LabelEncoder()
cn2 = list(dataset['MaritalStatus'].values)
le.fit(list(set(cn2)))
num_cn2 = list(le.transform(cn2))
dataset['MaritalStatus'] = num_cn2


le = LabelEncoder()
cn3 = list(dataset['OverTime'].values)
le.fit(list(set(cn3)))
num_cn3 = list(le.transform(cn3))
dataset['OverTime'] = num_cn3
le = LabelEncoder()
cn3 = list(dataset['Over18'].values)
le.fit(list(set(cn3)))
num_cn3 = list(le.transform(cn3))
dataset['Over18'] = num_cn3

# %%
dataset.head(100)
# Out:
#           Age  Attrition  BusinessTravel    DailyRate  Department  \
# 0   41.920786          1               2   990.110009           2
# 1   51.589037          0               1   276.776030           1
# 2   33.131540          1               2  1204.158501           1
# 3   34.707073          0               1  1352.752432           2
# 4   24.790188          0               2   485.053333           1
# ..        ...        ...             ...          ...         ...
# 95  52.753286          0               3  1348.645146           3
# 96  24.972219          0               2  1418.013314           2
# 97  29.450048          2               0   121.542946           3
# 98  54.795718          1               2   696.275160           2
# 99  31.069946          0               0   472.075616           0
#
#     DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0           1.016716   1.770313               1       1.033298
# 1                NaN   1.035333               1       0.944859
# 2           2.198662   2.118801               4       0.810809
# 3           2.937851   3.670674               1       0.822976
# 4           1.988953   1.120496               3            NaN
# ..               ...        ...             ...            ...
# 95          1.710806   4.610539               5       1.052811
# 96          2.992013   2.121171               4       0.874971
# 97          3.489764   3.029297               3       0.957383
# 98          9.713071   3.870543               3       1.025315
# 99         21.860904   2.914781               3       0.991794
#
#     EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0         1.054148                 2.146294       1   93.827486
# 1         2.107031                 3.470803       1   52.304157
# 2         4.008125                 3.979420       1   87.271332
# 3         4.587269                 3.734705       0   56.378982
# 4         7.228740                 1.079412       1   40.433887
# ..             ...                      ...     ...         ...
# 95      142.081746                 1.108846       0   50.510687
# 96      124.590183                 1.082230       0   28.915605
# 97      124.733093                 1.972241       1   55.490130
# 98      112.563069                 3.747373       1   37.539190
# 99      127.032155                 1.985621       1   61.347746
#
#     JobInvolvement  JobLevel  JobRole  JobSatisfaction  MaritalStatus  \
# 0         3.426960  2.464492        7         3.397665              2
# 1         1.813458  1.788697        6         1.584059              1
# 2         1.877226  0.833488        2         3.301009              2
# 3         2.932646  1.095372        6         3.220844              1
# 4         3.117739  0.937746        2         1.697330              1
# ..             ...       ...      ...              ...            ...
# 95        2.970304  3.026886        5         2.962701              1
# 96             NaN  1.636080        7         2.565086              1
# 97        2.468204  1.911887        7         3.229413              1
# 98        3.164950  3.197332        7         3.210624              2
# 99        3.105731  2.131153        2         1.954840              1
#
#     MonthlyIncome   MonthlyRate  NumCompaniesWorked  Over18  OverTime  \
# 0     6438.949336  20845.103714            7.077818       0         1
# 1     4457.659622  24877.898697            1.114423       0         0
# 2     2124.545220   2262.942954            5.539591       0         1
# 3     2771.699080  27189.905714            0.772793       1         1
# 4     3254.601575  17675.541599           10.118125       1         2
# ..            ...           ...                 ...     ...       ...
# 95   12781.892327  24273.012011            7.730572       0         0
# 96    5361.519600  15109.699029            0.000000       0         0
# 97    4363.225244   9584.040191            1.156614       0         0
# 98   13281.793183  23364.541815            0.000000       0         0
# 99    2200.412585  21080.994029            4.071301       0         0
#
#     PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 0            9.898765           2.844897                  1.012832
# 1                 NaN           4.120281                  4.312008
# 2           15.401596           2.781168                  2.332558
# 3            9.757546           2.769576                  3.029591
# 4           11.920147           3.282183                       NaN
# ..                ...                ...                       ...
# 95                NaN           3.335369                  0.918787
# 96          20.037946                NaN                  1.042048
# 97          13.705635           3.363873                  1.884155
# 98          14.669386                NaN                  3.199059
# 99          12.591281           2.992472                  2.814260
#
#     StandardHours  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0       95.612654          0.000000           8.063833               0.000000
# 1       85.370868          1.104642           8.965059               3.264952
# 2       76.248084          0.000000           8.427238               3.004521
# 3       75.888697          0.000000           7.662606               2.856001
# 4       72.670937          0.953012           6.241733               2.814719
# ..            ...               ...                ...                    ...
# 95      80.180627          1.024957          17.945258               5.833206
# 96      83.691722          0.846679           4.727456               2.126945
# 97      81.129612          0.000000           4.896806               2.991665
# 98      80.244487          0.000000          43.621947               1.024920
# 99      84.700866          0.878569          19.589473               2.733381
#
#     WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0          1.052104        5.795945            3.993896
# 1          2.526470       10.070232            7.937505
# 2          2.924784        0.000000            0.000000
# 3          3.117053        8.435324            5.563667
# 4          3.112317        2.040124            1.970786
# ..              ...             ...                 ...
# 95         0.978528        3.881292            3.634240
# 96         1.846016             NaN            2.239032
# 97         4.856086        4.894706            3.354764
# 98              NaN       35.421655           10.719625
# 99         3.920447        2.954118            2.094521
#
#     YearsSinceLastPromotion  YearsWithCurrManager
# 0                  0.000000              4.594972
# 1                  1.032295              5.901207
# 2                  0.000000              0.000000
# 3                  2.845429              0.000000
# 4                  2.495949              2.219353
# ..                      ...                   ...
# 95                 0.000000              3.340230
# 96                 0.000000              2.186007
# 97                 0.000000              3.919254
# 98                 1.023825              6.673827
# 99                 0.894036              2.175621
#
# [100 rows x 35 columns]

# %% [markdown]
# Now the categorical variable bacame binary and it needs to be started handling the missing variable inside before proceeding with the next steps.If the missing variable will be dropped the dataset will be left with no enought obeservation. To handle the missing variable no there is the risk of the choice so it is wise to use different method for each features.

# %% [markdown]
# For Binary Variable nit couldn't be used in this case the median due that for example in the column gender if we fill with the median won't be accurate to identify the male or female. it will be filed with the mode the risk is if in the dataset are present 10 men, 5 women and 10 missing variable if it is filled with the mode ( th emost frequent variable) it will be assumed that the missing variable will be male and this could be not accurate.

# %%
from sklearn.impute import SimpleImputer
imputer= SimpleImputer(strategy='most_frequent')
dataset['binary_variable']= imputer.fit_transform(dataset[['Gender']])

# %%
from sklearn.impute import SimpleImputer
imputer= SimpleImputer(strategy='most_frequent')
dataset['binary_variable']= imputer.fit_transform(dataset[['MaritalStatus']])

# %%
dataset.isnull().sum()
# Out:
# Age                         147
# Attrition                     0
# BusinessTravel                0
# DailyRate                   147
# Department                    0
# DistanceFromHome            147
# Education                   147
# EducationField                0
# EmployeeCount               147
# EmployeeNumber              147
# EnvironmentSatisfaction     147
# Gender                        0
# HourlyRate                  147
# JobInvolvement              147
# JobLevel                    147
# JobRole                       0
# JobSatisfaction             147
# MaritalStatus                 0
# MonthlyIncome               147
# MonthlyRate                 147
# NumCompaniesWorked          147
# Over18                        0
# OverTime                      0
# PercentSalaryHike           147
# PerformanceRating           147
# RelationshipSatisfaction    147
# StandardHours               147
# StockOptionLevel            147
# TotalWorkingYears           147
# TrainingTimesLastYear       147
# WorkLifeBalance             147
# YearsAtCompany              147
# YearsInCurrentRole          147
# YearsSinceLastPromotion     147
# YearsWithCurrManager        147
# binary_variable               0
# dtype: int64

# %% [markdown]
# The rest can be filled with the median:

# %%
dataset.fillna(dataset.median(),inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# binary_variable             0
# dtype: int64

# %% [markdown]
# The missing values has been handled.

# %% [markdown]
# # Convert Float into Integers:

# %%
display(dataset.dtypes)
 
dataset['Age'] = dataset['Age'].apply(np.int64)
dataset['DailyRate'] = dataset['DailyRate'].apply(np.int64)
dataset['DistanceFromHome'] = dataset['DistanceFromHome'].apply(np.int64)
dataset['Education'] = dataset['Education'].apply(np.int64)
dataset['EmployeeCount'] = dataset['EmployeeCount'].apply(np.int64)
dataset['EmployeeNumber'] = dataset['EmployeeNumber'].apply(np.int64)
dataset['EnvironmentSatisfaction'] = dataset['EnvironmentSatisfaction'].apply(np.int64)
dataset['HourlyRate'] = dataset['HourlyRate'].apply(np.int64)
dataset['JobInvolvement'] = dataset['JobInvolvement'].apply(np.int64)
dataset['JobLevel'] = dataset['JobLevel'].apply(np.int64)
dataset['JobSatisfaction'] = dataset['JobSatisfaction'].apply(np.int64)
dataset['MonthlyRate'] = dataset['MonthlyRate'].apply(np.int64)
dataset['MonthlyIncome'] = dataset['MonthlyIncome'].apply(np.int64)
dataset['MonthlyRate'] = dataset['MonthlyRate'].apply(np.int64)
dataset['JobSatisfaction'] = dataset['JobSatisfaction'].apply(np.int64)
dataset['NumCompaniesWorked'] = dataset['NumCompaniesWorked'].apply(np.int64)
dataset['MonthlyIncome'] = dataset['MonthlyIncome'].apply(np.int64)
dataset['PercentSalaryHike'] = dataset['PercentSalaryHike'].apply(np.int64)
dataset['PerformanceRating'] = dataset['PerformanceRating'].apply(np.int64)
dataset['RelationshipSatisfaction'] = dataset['RelationshipSatisfaction'].apply(np.int64)
dataset['JobSatisfaction'] = dataset['JobSatisfaction'].apply(np.int64)
dataset['StandardHours'] = dataset['StandardHours'].apply(np.int64)
dataset['StockOptionLevel'] = dataset['StockOptionLevel'].apply(np.int64)
dataset['TotalWorkingYears'] = dataset['TotalWorkingYears'].apply(np.int64)
dataset['TrainingTimesLastYear'] = dataset['TrainingTimesLastYear'].apply(np.int64)
dataset['WorkLifeBalance'] = dataset['WorkLifeBalance'].apply(np.int64)
dataset['YearsAtCompany'] = dataset['YearsAtCompany'].apply(np.int64)
dataset['YearsInCurrentRole'] = dataset['YearsInCurrentRole'].apply(np.int64)
dataset['YearsSinceLastPromotion'] = dataset['YearsSinceLastPromotion'].apply(np.int64)
dataset['YearsWithCurrManager'] = dataset['YearsWithCurrManager'].apply(np.int64)
# Out:
# Age                         float64
# Attrition                     int32
# BusinessTravel                int32
# DailyRate                   float64
# Department                    int32
# DistanceFromHome            float64
# Education                   float64
# EducationField                int32
# EmployeeCount               float64
# EmployeeNumber              float64
# EnvironmentSatisfaction     float64
# Gender                        int32
# HourlyRate                  float64
# JobInvolvement              float64
# JobLevel                    float64
# JobRole                       int32
# JobSatisfaction             float64
# MaritalStatus                 int32
# MonthlyIncome               float64
# MonthlyRate                 float64
# NumCompaniesWorked          float64
# Over18                        int32
# OverTime                      int32
# PercentSalaryHike           float64
# PerformanceRating           float64
# RelationshipSatisfaction    float64
# StandardHours               float64
# StockOptionLevel            float64
# TotalWorkingYears           float64
# TrainingTimesLastYear       float64
# WorkLifeBalance             float64
# YearsAtCompany              float64
# YearsInCurrentRole          float64
# YearsSinceLastPromotion     float64
# YearsWithCurrManager        float64
# binary_variable               int32
# dtype: object

# %%
display(dataset.dtypes)
# Out:
# Age                         int64
# Attrition                   int32
# BusinessTravel              int32
# DailyRate                   int64
# Department                  int32
# DistanceFromHome            int64
# Education                   int64
# EducationField              int32
# EmployeeCount               int64
# EmployeeNumber              int64
# EnvironmentSatisfaction     int64
# Gender                      int32
# HourlyRate                  int64
# JobInvolvement              int64
# JobLevel                    int64
# JobRole                     int32
# JobSatisfaction             int64
# MaritalStatus               int32
# MonthlyIncome               int64
# MonthlyRate                 int64
# NumCompaniesWorked          int64
# Over18                      int32
# OverTime                    int32
# PercentSalaryHike           int64
# PerformanceRating           int64
# RelationshipSatisfaction    int64
# StandardHours               int64
# StockOptionLevel            int64
# TotalWorkingYears           int64
# TrainingTimesLastYear       int64
# WorkLifeBalance             int64
# YearsAtCompany              int64
# YearsInCurrentRole          int64
# YearsSinceLastPromotion     int64
# YearsWithCurrManager        int64
# binary_variable             int32
# dtype: object

# %%
dataset.head(100)
# Out:
#     Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0    41          1               2        990           2                 1
# 1    51          0               1        276           1                 6
# 2    33          1               2       1204           1                 2
# 3    34          0               1       1352           2                 2
# 4    24          0               2        485           1                 1
# ..  ...        ...             ...        ...         ...               ...
# 95   52          0               3       1348           3                 1
# 96   24          0               2       1418           2                 2
# 97   29          2               0        121           3                 3
# 98   54          1               2        696           2                 9
# 99   31          0               0        472           0                21
#
#     Education  EducationField  EmployeeCount  EmployeeNumber  \
# 0           1               1              1               1
# 1           1               1              0               2
# 2           2               4              0               4
# 3           3               1              0               4
# 4           1               3              0               7
# ..        ...             ...            ...             ...
# 95          4               5              1             142
# 96          2               4              0             124
# 97          3               3              0             124
# 98          3               3              1             112
# 99          2               3              0             127
#
#     EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                         2       1          93               3         2
# 1                         3       1          52               1         1
# 2                         3       1          87               1         0
# 3                         3       0          56               2         1
# 4                         1       1          40               3         0
# ..                      ...     ...         ...             ...       ...
# 95                        1       0          50               2         3
# 96                        1       0          28               2         1
# 97                        1       1          55               2         1
# 98                        3       1          37               3         3
# 99                        1       1          61               3         2
#
#     JobRole  JobSatisfaction  MaritalStatus  MonthlyIncome  MonthlyRate  \
# 0         7                3              2           6438        20845
# 1         6                1              1           4457        24877
# 2         2                3              2           2124         2262
# 3         6                3              1           2771        27189
# 4         2                1              1           3254        17675
# ..      ...              ...            ...            ...          ...
# 95        5                2              1          12781        24273
# 96        7                2              1           5361        15109
# 97        7                3              1           4363         9584
# 98        7                3              2          13281        23364
# 99        2                1              1           2200        21080
#
#     NumCompaniesWorked  Over18  OverTime  PercentSalaryHike  \
# 0                    7       0         1                  9
# 1                    1       0         0                 14
# 2                    5       0         1                 15
# 3                    0       1         1                  9
# 4                   10       1         2                 11
# ..                 ...     ...       ...                ...
# 95                   7       0         0                 14
# 96                   0       0         0                 20
# 97                   1       0         0                 13
# 98                   0       0         0                 14
# 99                   4       0         0                 12
#
#     PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                   2                         1             95
# 1                   4                         4             85
# 2                   2                         2             76
# 3                   2                         3             75
# 4                   3                         2             72
# ..                ...                       ...            ...
# 95                  3                         0             80
# 96                  3                         1             83
# 97                  3                         1             81
# 98                  3                         3             80
# 99                  2                         2             84
#
#     StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                  0                  8                      0
# 1                  1                  8                      3
# 2                  0                  8                      3
# 3                  0                  7                      2
# 4                  0                  6                      2
# ..               ...                ...                    ...
# 95                 1                 17                      5
# 96                 0                  4                      2
# 97                 0                  4                      2
# 98                 0                 43                      1
# 99                 0                 19                      2
#
#     WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                 1               5                   3
# 1                 2              10                   7
# 2                 2               0                   0
# 3                 3               8                   5
# 4                 3               2                   1
# ..              ...             ...                 ...
# 95                0               3                   3
# 96                1               5                   2
# 97                4               4                   3
# 98                2              35                  10
# 99                3               2                   2
#
#     YearsSinceLastPromotion  YearsWithCurrManager  binary_variable
# 0                         0                     4                2
# 1                         1                     5                1
# 2                         0                     0                2
# 3                         2                     0                1
# 4                         2                     2                1
# ..                      ...                   ...              ...
# 95                        0                     3                1
# 96                        0                     2                1
# 97                        0                     3                1
# 98                        1                     6                2
# 99                        0                     2                1
#
# [100 rows x 36 columns]

# %%
plt.hist(dataset['DistanceFromHome'], bins=20, edgecolor='black')
plt.xlabel('DistanceFromHome')
plt.ylabel('Frequency')
plt.title('Distribution of distance from home')
plt.show()

# %% [markdown]
# The higher distribution of the age is between 30/40 years old

# %%
plt.hist(dataset['PerformanceRating'], bins=20, edgecolor='black')
plt.xlabel('PerformanceRating')
plt.ylabel('Frequency')
plt.title('Distribution of perfomance')
plt.show()

# %%
plt.hist(dataset['MonthlyIncome'], bins=20, edgecolor='black')
plt.xlabel('MonthlyIncome')
plt.ylabel('Frequency')
plt.title('Distribution of income monthly')
plt.show()

# %%
plt.figure(figsize=(10, 7))
sns.countplot(data=dataset, x='StandardHours', palette='pastel')
plt.title('Distribution of Standard Hours')
plt.xlabel('Standard Hours')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# check for outliners with the boxplot:

# %%
numerical_columns = dataset.select_dtypes(include=['int64', 'float64']).columns
num_cols = len(numerical_columns)

# Calculate the number of rows and columns needed for subplots
num_rows = (num_cols - 1) // 3 + 1  # Adjust the number of columns per row here (currently 3)

plt.figure(figsize=(15, 5 * num_rows))
for i, column in enumerate(numerical_columns):
    plt.subplot(num_rows, 3, i + 1)  # Adjust the number of columns per row here
    sns.boxplot(x=dataset[column])
    plt.title(column)
    plt.tight_layout()

plt.show()

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA

# %% [markdown]
# my target variabel is jobsatisfaction

# %%
dataset_no_label = dataset.drop(columns=["JobRole"])

# %%
dataset_no_label.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2        990           2                 1
# 1   51          0               1        276           1                 6
# 2   33          1               2       1204           1                 2
# 3   34          0               1       1352           2                 2
# 4   24          0               2        485           1                 1
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  \
# 0          1               1              1               1
# 1          1               1              0               2
# 2          2               4              0               4
# 3          3               1              0               4
# 4          1               3              0               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2       1          93               3         2
# 1                        3       1          52               1         1
# 2                        3       1          87               1         0
# 3                        3       0          56               2         1
# 4                        1       1          40               3         0
#
#    JobRole  MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked  \
# 0        7              2           6438        20845                   7
# 1        6              1           4457        24877                   1
# 2        2              2           2124         2262                   5
# 3        6              1           2771        27189                   0
# 4        2              1           3254        17675                  10
#
#    Over18  OverTime  PercentSalaryHike  PerformanceRating  \
# 0       0         1                  9                  2
# 1       0         0                 14                  4
# 2       0         1                 15                  2
# 3       1         1                  9                  2
# 4       1         2                 11                  3
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             95                 0
# 1                         4             85                 1
# 2                         2             76                 0
# 3                         3             75                 0
# 4                         2             72                 0
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0                1               5
# 1                  8                      3                2              10
# 2                  8                      3                2               0
# 3                  7                      2                3               8
# 4                  6                      2                3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                   3                        0                     4
# 1                   7                        1                     5
# 2                   0                        0                     0
# 3                   5                        2                     0
# 4                   1                        2                     2
#
#    binary_variable
# 0                2
# 1                1
# 2                2
# 3                1
# 4                1

# %%
pca = PCA().fit(dataset_no_label) 
plt.plot(np.cumsum(pca.explained_variance_ratio_)) 
plt.xlabel('number of components') 
plt.ylabel('cumulative explained variance');
plt.axhline(0.9950,color= "orangered",alpha=.5,ls="--")
plt.axvline(2,color= "orangered",alpha=.5,ls="--");
plt.xlim(0,5)
# Out:
# (0.0, 5.0)

# %%
pca = PCA(1)
projected = pca.fit_transform(dataset_no_label)

# %%
projected.shape
# Out:
# (1470, 1)

# %%
projected
# Out:
# array([[  6485.0133],
#        [ 10426.4485],
#        [-12272.5259],
#        ...,
#        [   -83.4364],
#        [ -2547.8502],
#        [ -4126.3678]])

# %%
dataset_pca = pd.DataFrame(projected, columns =['C1'])

# %%
dataset_pca["JobRole"] = dataset["JobRole"]

# %%
dataset_pca.head()
# Out:
#              C1  JobRole
# 0   6485.013279        7
# 1  10426.448537        6
# 2 -12272.525943        2
# 3  12657.967033        6
# 4   3177.408437        2

# %% [markdown]
# # LDA

# %%
from sklearn.datasets import make_blobs
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
# %matplotlib inline

n_train = 20  # samples for training
n_test = 200  # samples for testing
n_averages = 50  # how often to repeat classification
n_features_max = 75  # maximum number of features
step = 4  # step size for the calculation


def generate_data(n_samples, n_features):
    """Generate random blob-ish data with noisy features.

    This returns an array of input data with shape `(n_samples, n_features)`
    and an array of `n_samples` target labels.

    Only one feature contains discriminative information, the other features
    contain only noise.
    """
    X, y = make_blobs(n_samples=n_samples, n_features=1, centers=[[-2], [2]])

    # add non-discriminative features
    if n_features > 1:
        X = np.hstack([X, np.random.randn(n_samples, n_features - 1)])
    return X, y

acc_clf1, acc_clf2 = [], []
n_features_range = range(1, n_features_max + 1, step)
for n_features in n_features_range:
    score_clf1, score_clf2 = 0, 0
    for _ in range(n_averages):
        X, y = generate_data(n_train, n_features)

        clf1 = LinearDiscriminantAnalysis(solver='lsqr', shrinkage=0.5).fit(X, y)
        clf2 = LinearDiscriminantAnalysis(solver='lsqr', shrinkage=None).fit(X, y)

        X, y = generate_data(n_test, n_features)
        score_clf1 += clf1.score(X, y)
        score_clf2 += clf2.score(X, y)

    acc_clf1.append(score_clf1 / n_averages)
    acc_clf2.append(score_clf2 / n_averages)

features_samples_ratio = np.array(n_features_range) / n_train

with plt.style.context('seaborn-talk'):
    plt.plot(features_samples_ratio, acc_clf1, linewidth=2,
             label="LDA with shrinkage", color='navy')
    plt.plot(features_samples_ratio, acc_clf2, linewidth=2,
             label="LDA", color='gold')

    plt.xlabel('n_features / n_samples')
    plt.ylabel('Classification accuracy')
    plt.legend(prop={'size': 18})
    plt.tight_layout()

# %%
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.decomposition import PCA
# %matplotlib inline

X = dataset
y = dataset.JobSatisfaction
target_names = dataset.JobSatisfaction

X_r_lda = LinearDiscriminantAnalysis(n_components=2).fit(X, y).transform(X)
X_r_pca = PCA(n_components=2).fit(X).transform(X)

with plt.style.context('seaborn-talk'):
    fig, axes = plt.subplots(1,2,figsize=[15,6])
    colors = ['navy', 'turquoise', 'darkorange']
    for color, i, target_name in zip(colors, [0, 1, 2], target_names):
        axes[0].scatter(X_r_lda[y == i, 0], X_r_lda[y == i, 1], alpha=.8, label=target_name, color=color)
        axes[1].scatter(X_r_pca[y == i, 0], X_r_pca[y == i, 1], alpha=.8, label=target_name, color=color)
    axes[0].title.set_text('LDA for the dataset')
    axes[1].title.set_text('PCA for the dataset')
    axes[0].set_xlabel('Discriminant Coordinate 1')
    axes[0].set_ylabel('Discriminant Coordinate 2')
    axes[1].set_xlabel('PC 1')
    axes[1].set_ylabel('PC 2')

# %%
lda=LinearDiscriminantAnalysis()
easy_lda=lda.fit_transform(X,y)

# %%
plt.xlabel("LD1")
plt.ylabel("LD2")
plt.scatter(
easy_lda[:,0],
easy_lda[:,1],
c=y,
cmap="rainbow",
alpha=0.7,
edgecolors="b")

# %%
X_pca=pca.fit_transform(X,y)
y_pca=pca.fit_transform(X,y)

# %%
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.scatter(
X_pca[:,0],
y_pca[:,1],
c=y,
cmap="rainbow",
alpha=0.7,
edgecolors="b")

# %%
import pandas as pd
import numpy as np
np.set_printoptions(precision=4)
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42) #1/3 of the dataset

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
y_pred = dt.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 45,   0,   0,   0,   0],
#        [  0,  85,   0,   0,   0],
#        [  0,   0, 165,   0,   0],
#        [  0,   0,   0, 127,   0],
#        [  0,   0,   0,   0,  64]], dtype=int64)

# %% [markdown]
# # Statistical Techniques:

# %% [markdown]
# Use descriptive statistical analyses to explore and evaluate the data set, including measures of
# central tendency and dispersion and frequency distributions. Correlation matrices are also
# accepted. Provide a summary of your findings. (0-30 marks)

# %% [markdown]
# Measure of Central Tendecy: MEAN, MEDIAN, MODE, STANDARD DEVIATION
#
# Measure of dispersion: Standard Deviation

# %%
dataset.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2        990           2                 1
# 1   51          0               1        276           1                 6
# 2   33          1               2       1204           1                 2
# 3   34          0               1       1352           2                 2
# 4   24          0               2        485           1                 1
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  \
# 0          1               1              1               1
# 1          1               1              0               2
# 2          2               4              0               4
# 3          3               1              0               4
# 4          1               3              0               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2       1          93               3         2
# 1                        3       1          52               1         1
# 2                        3       1          87               1         0
# 3                        3       0          56               2         1
# 4                        1       1          40               3         0
#
#    JobRole  JobSatisfaction  MaritalStatus  MonthlyIncome  MonthlyRate  \
# 0        7                3              2           6438        20845
# 1        6                1              1           4457        24877
# 2        2                3              2           2124         2262
# 3        6                3              1           2771        27189
# 4        2                1              1           3254        17675
#
#    NumCompaniesWorked  Over18  OverTime  PercentSalaryHike  PerformanceRating  \
# 0                   7       0         1                  9                  2
# 1                   1       0         0                 14                  4
# 2                   5       0         1                 15                  2
# 3                   0       1         1                  9                  2
# 4                  10       1         2                 11                  3
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             95                 0
# 1                         4             85                 1
# 2                         2             76                 0
# 3                         3             75                 0
# 4                         2             72                 0
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0                1               5
# 1                  8                      3                2              10
# 2                  8                      3                2               0
# 3                  7                      2                3               8
# 4                  6                      2                3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                   3                        0                     4
# 1                   7                        1                     5
# 2                   0                        0                     0
# 3                   5                        2                     0
# 4                   1                        2                     2
#
#    binary_variable
# 0                2
# 1                1
# 2                2
# 3                1
# 4                1

# %% [markdown]
# The variable that are considered for the analysis are:
# - Job Satisfaction---> target variable
# - PerformanceRating---> input variable
# - RelationshipSatisfaction---> input variable
# - JobRole--input variable for worklife balance
# - monthly income--> Input variable for worklife balance
# - distance from home--? input variable for worklife balance

# %% [markdown]
# JobSatisfaction:

# %%
mean_adm= dataset['JobSatisfaction'].mean() #meanistheaverage
print(mean_adm)
median = dataset['JobSatisfaction'].median()
print(median)
mode = dataset['JobSatisfaction'].mode()
print(mode)
std_dev_balance = dataset['JobSatisfaction'].std()

print(f"The standard deviation of the 'JobSatisfaction' column is: {std_dev_balance}")
# Out:
# 2.1904761904761907
# 2.0
# 0    2
# Name: JobSatisfaction, dtype: int64
# The standard deviation of the 'JobSatisfaction' column is: 1.1481973519674757

# %% [markdown]
# Performance Rating:

# %%
mean_adm= dataset['PerformanceRating'].mean() #meanistheaverage
print(mean_adm)
median = dataset['PerformanceRating'].median()
print(median)
mode = dataset['PerformanceRating'].mode()
print(mode)
std_dev_balance = dataset['PerformanceRating'].std()

print(f"The standard deviation of the 'PerformanceRating' column is: {std_dev_balance}")
# Out:
# 2.6863945578231294
# 3.0
# 0    3
# Name: PerformanceRating, dtype: int64
# The standard deviation of the 'PerformanceRating' column is: 0.5917678347885345

# %% [markdown]
# RelationshipSatisfaction

# %%
mean_adm= dataset['RelationshipSatisfaction'].mean() #meanistheaverage
print(mean_adm)
median = dataset['RelationshipSatisfaction'].median()
print(median)
mode = dataset['RelationshipSatisfaction'].mode()
print(mode)
std_dev_balance = dataset['RelationshipSatisfaction'].std()

print(f"The standard deviation of the 'RelationshipSatisfaction' column is: {std_dev_balance}")
# Out:
# 2.216326530612245
# 2.0
# 0    2
# Name: RelationshipSatisfaction, dtype: int64
# The standard deviation of the 'RelationshipSatisfaction' column is: 1.1298319312307796

# %% [markdown]
# JobRole:

# %%
mean_adm= dataset['JobRole'].mean() #meanistheaverage
print(mean_adm)
median = dataset['JobRole'].median()
print(median)
mode = dataset['JobRole'].mode()
print(mode)
std_dev_balance = dataset['JobRole'].std()

print(f"The standard deviation of the 'JobRole' column is: {std_dev_balance}")
# Out:
# 4.857823129251701
# 6.0
# 0    7
# Name: JobRole, dtype: int32
# The standard deviation of the 'JobRole' column is: 2.720880237632336

# %% [markdown]
# MonthlyIncome

# %%
mean_adm= dataset['MonthlyIncome'].mean() #meanistheaverage
print(mean_adm)
median = dataset['MonthlyIncome'].median()
print(median)
mode = dataset['MonthlyIncome'].mode()
print(mode)
std_dev_balance = dataset['MonthlyIncome'].std()

print(f"The standard deviation of the 'MonthlyIncome' column is: {std_dev_balance}")
# Out:
# 6385.495238095238
# 4957.0
# 0    4957
# Name: MonthlyIncome, dtype: int64
# The standard deviation of the 'MonthlyIncome' column is: 4546.827522688763

# %% [markdown]
# DistanceFromHome

# %%
mean_adm= dataset['DistanceFromHome'].mean() #meanistheaverage
print(mean_adm)
median = dataset['DistanceFromHome'].median()
print(median)
mode = dataset['DistanceFromHome'].mode()
print(mode)
std_dev_balance = dataset['DistanceFromHome'].std()

print(f"The standard deviation of the 'DistanceFromHome' column is: {std_dev_balance}")
# Out:
# 8.345578231292517
# 6.0
# 0    6
# Name: DistanceFromHome, dtype: int64
# The standard deviation of the 'DistanceFromHome' column is: 7.802464494257019

# %% [markdown]
# # Frequency:

# %%
dataset.PerformanceRating.value_counts()
value_counts = dataset['JobSatisfaction'].value_counts()
relative_frequencies = value_counts / len(dataset)
subtable = pd.DataFrame({'JobSatisfaction': value_counts.index, 
                         'Frequency': value_counts.values, 
                         'Relative Frequency': relative_frequencies.values})
subtable
# Out:
#    JobSatisfaction  Frequency  Relative Frequency
# 0                2        463            0.314966
# 1                3        406            0.276190
# 2                1        275            0.187075
# 3                4        199            0.135374
# 4                0        126            0.085714
# 5                5          1            0.000680

# %%
dataset.PerformanceRating.value_counts()
value_counts = dataset['PerformanceRating'].value_counts()
relative_frequencies = value_counts / len(dataset)
subtable = pd.DataFrame({'PerformanceRating': value_counts.index, 
                         'Frequency': value_counts.values, 
                         'Relative Frequency': relative_frequencies.values})
subtable
# Out:
#    PerformanceRating  Frequency  Relative Frequency
# 0                  3        814            0.553741
# 1                  2        559            0.380272
# 2                  4         96            0.065306
# 3                  5          1            0.000680

# %%
dataset.RelationshipSatisfaction.value_counts()
value_counts = dataset['RelationshipSatisfaction'].value_counts()
relative_frequencies = value_counts / len(dataset)
subtable = pd.DataFrame({'RelationshipSatisfaction': value_counts.index, 
                         'Frequency': value_counts.values, 
                         'Relative Frequency': relative_frequencies.values})
subtable
# Out:
#    RelationshipSatisfaction  Frequency  Relative Frequency
# 0                         2        485            0.329932
# 1                         3        404            0.274830
# 2                         1        263            0.178912
# 3                         4        202            0.137415
# 4                         0        115            0.078231
# 5                         5          1            0.000680

# %%
dataset.JobRole.value_counts()
value_counts = dataset['JobRole'].value_counts()
relative_frequencies = value_counts / len(dataset)
subtable = pd.DataFrame({'JobRole': value_counts.index, 
                         'Frequency': value_counts.values, 
                         'Relative Frequency': relative_frequencies.values})
subtable
# Out:
#    JobRole  Frequency  Relative Frequency
# 0        7        281            0.191156
# 1        6        257            0.174830
# 2        2        229            0.155782
# 3        9        147            0.100000
# 4        4        122            0.082993
# 5        0        118            0.080272
# 6        3        101            0.068707
# 7        5         80            0.054422
# 8        8         75            0.051020
# 9        1         60            0.040816

# %%
dataset.MonthlyIncome.value_counts()
value_counts = dataset['MonthlyIncome'].value_counts()
relative_frequencies = value_counts / len(dataset)
subtable = pd.DataFrame({'MonthlyIncome': value_counts.index, 
                         'Frequency': value_counts.values, 
                         'Relative Frequency': relative_frequencies.values})
subtable
# Out:
#       MonthlyIncome  Frequency  Relative Frequency
# 0              4957        148            0.100680
# 1              2392          3            0.002041
# 2              6438          2            0.001361
# 3              2698          2            0.001361
# 4              2230          2            0.001361
# ...             ...        ...                 ...
# 1244           2351          1            0.000680
# 1245           7869          1            0.000680
# 1246           2568          1            0.000680
# 1247          18853          1            0.000680
# 1248           5188          1            0.000680
#
# [1249 rows x 3 columns]

# %%
dataset.DistanceFromHome.value_counts()
value_counts = dataset['DistanceFromHome'].value_counts()
relative_frequencies = value_counts / len(dataset)
subtable = pd.DataFrame({'DistanceFromHome': value_counts.index, 
                         'Frequency': value_counts.values, 
                         'Relative Frequency': relative_frequencies.values})
subtable
# Out:
#     DistanceFromHome  Frequency  Relative Frequency
# 0                  6        204            0.138776
# 1                  1        191            0.129932
# 2                  2        154            0.104762
# 3                  8         90            0.061224
# 4                  0         89            0.060544
# 5                  7         76            0.051701
# 6                  4         73            0.049660
# 7                  9         64            0.043537
# 8                  5         51            0.034694
# 9                  3         51            0.034694
# 10                10         35            0.023810
# 11                11         32            0.021769
# 12                18         31            0.021088
# 13                15         28            0.019048
# 14                16         26            0.017687
# 15                23         24            0.016327
# 16                24         22            0.014966
# 17                21         21            0.014286
# 18                22         20            0.013605
# 19                13         20            0.013605
# 20                26         20            0.013605
# 21                12         20            0.013605
# 22                25         16            0.010884
# 23                14         16            0.010884
# 24                19         15            0.010204
# 25                17         15            0.010204
# 26                20         14            0.009524
# 27                28         13            0.008844
# 28                27         12            0.008163
# 29                29         11            0.007483
# 30                30          9            0.006122
# 31                31          6            0.004082
# 32                33          1            0.000680

# %% [markdown]
# correlation matrix:

# %%
numerical_data = dataset.select_dtypes(include=['float64', 'int64'])  # Select numerical columns
correlation_matrix = numerical_data.corr()

# Print correlation matrix
print("\nCorrelation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.005298         -0.005899   0.180209
# DailyRate                 0.005298   1.000000         -0.000527  -0.020271
# DistanceFromHome         -0.005899  -0.000527          1.000000   0.007398
# Education                 0.180209  -0.020271          0.007398   1.000000
# EmployeeCount            -0.025486   0.025224         -0.006846  -0.037186
# EmployeeNumber           -0.008011  -0.044616          0.029362   0.024615
# EnvironmentSatisfaction   0.001580   0.012311         -0.025634  -0.011434
# HourlyRate                0.023975   0.027822          0.022841   0.006409
# JobInvolvement            0.013801   0.053695          0.002524   0.029499
# JobLevel                  0.386272  -0.013052          0.017040   0.073776
# JobSatisfaction          -0.006668   0.034426          0.020306   0.018595
# MonthlyIncome             0.394158   0.012438         -0.007354   0.069632
# MonthlyRate               0.026194  -0.047495          0.012661  -0.013364
# NumCompaniesWorked        0.242811   0.067844         -0.005975   0.110197
# PercentSalaryHike         0.000531   0.013789          0.043854  -0.024706
# PerformanceRating         0.007625   0.006227         -0.018826  -0.025934
# RelationshipSatisfaction  0.016557   0.015816          0.016533  -0.028595
# StandardHours             0.003184  -0.034749         -0.004839  -0.001738
# StockOptionLevel          0.022496  -0.005738          0.022948   0.006493
# TotalWorkingYears         0.565104   0.013246         -0.000803   0.121545
# TrainingTimesLastYear    -0.027055  -0.000828         -0.028438  -0.025671
# WorkLifeBalance          -0.029410  -0.023298         -0.004841   0.012570
# YearsAtCompany            0.242254  -0.034174          0.017098   0.062105
# YearsInCurrentRole        0.151734   0.001199          0.017368   0.069232
# YearsSinceLastPromotion   0.150223  -0.032508         -0.019859   0.040530
# YearsWithCurrManager      0.160209  -0.049434          0.036633   0.060829
#
#                           EmployeeCount  EmployeeNumber  \
# Age                           -0.025486       -0.008011
# DailyRate                      0.025224       -0.044616
# DistanceFromHome              -0.006846        0.029362
# Education                     -0.037186        0.024615
# EmployeeCount                  1.000000        0.042654
# EmployeeNumber                 0.042654        1.000000
# EnvironmentSatisfaction        0.021882        0.028791
# HourlyRate                     0.010852        0.003544
# JobInvolvement                 0.006892       -0.006275
# JobLevel                       0.032690       -0.008500
# JobSatisfaction                0.025556       -0.030397
# MonthlyIncome                 -0.000315       -0.013786
# MonthlyRate                   -0.058362        0.024262
# NumCompaniesWorked             0.018780       -0.025675
# PercentSalaryHike              0.001677       -0.019600
# PerformanceRating             -0.039111       -0.014001
# RelationshipSatisfaction       0.013965       -0.057390
# StandardHours                  0.022519        0.000468
# StockOptionLevel              -0.024769        0.041849
# TotalWorkingYears              0.000486       -0.020649
# TrainingTimesLastYear         -0.038604       -0.009689
# WorkLifeBalance               -0.014235        0.004054
# YearsAtCompany                 0.013620       -0.000139
# YearsInCurrentRole             0.010864       -0.014226
# YearsSinceLastPromotion       -0.002832       -0.009528
# YearsWithCurrManager          -0.043815       -0.021051
#
#                           EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# Age                                      0.001580    0.023975        0.013801
# DailyRate                                0.012311    0.027822        0.053695
# DistanceFromHome                        -0.025634    0.022841        0.002524
# Education                               -0.011434    0.006409        0.029499
# EmployeeCount                            0.021882    0.010852        0.006892
# EmployeeNumber                           0.028791    0.003544       -0.006275
# EnvironmentSatisfaction                  1.000000   -0.029592       -0.037553
# HourlyRate                              -0.029592    1.000000        0.023684
# JobInvolvement                          -0.037553    0.023684        1.000000
# JobLevel                                -0.002573   -0.019735        0.012879
# JobSatisfaction                         -0.036655   -0.045129       -0.037868
# MonthlyIncome                           -0.006560    0.021476        0.028304
# MonthlyRate                              0.017067   -0.013290       -0.005866
# NumCompaniesWorked                      -0.010102    0.033251        0.003752
# PercentSalaryHike                       -0.004322   -0.023512       -0.026202
# PerformanceRating                        0.015540   -0.012177       -0.004608
# RelationshipSatisfaction                 0.026868   -0.008126        0.007647
# StandardHours                           -0.018678   -0.013988       -0.002444
# StockOptionLevel                        -0.020219    0.024828       -0.027089
# TotalWorkingYears                       -0.001120    0.045075        0.021441
# TrainingTimesLastYear                   -0.018974   -0.018096       -0.011050
# WorkLifeBalance                          0.025012   -0.002544       -0.005309
# YearsAtCompany                          -0.022402    0.038194        0.001699
# YearsInCurrentRole                      -0.008779   -0.004516        0.024746
# YearsSinceLastPromotion                 -0.021576    0.005587        0.017100
# YearsWithCurrManager                    -0.050086    0.017230        0.037702
#
#                           JobLevel  JobSatisfaction  MonthlyIncome  \
# Age                       0.386272        -0.006668       0.394158
# DailyRate                -0.013052         0.034426       0.012438
# DistanceFromHome          0.017040         0.020306      -0.007354
# Education                 0.073776         0.018595       0.069632
# EmployeeCount             0.032690         0.025556      -0.000315
# EmployeeNumber           -0.008500        -0.030397      -0.013786
# EnvironmentSatisfaction  -0.002573        -0.036655      -0.006560
# HourlyRate               -0.019735        -0.045129       0.021476
# JobInvolvement            0.012879        -0.037868       0.028304
# JobLevel                  1.000000         0.003899       0.768606
# JobSatisfaction           0.003899         1.000000      -0.034155
# MonthlyIncome             0.768606        -0.034155       1.000000
# MonthlyRate               0.048162        -0.022179       0.038399
# NumCompaniesWorked        0.122163        -0.050632       0.136470
# PercentSalaryHike        -0.040647         0.020191      -0.019717
# PerformanceRating         0.003606         0.027861       0.016438
# RelationshipSatisfaction  0.027708        -0.016042       0.004406
# StandardHours             0.035952         0.028780       0.014685
# StockOptionLevel         -0.007489        -0.013806      -0.020070
# TotalWorkingYears         0.635438        -0.050177       0.681879
# TrainingTimesLastYear    -0.028062         0.003432      -0.044787
# WorkLifeBalance           0.022846        -0.034414       0.026940
# YearsAtCompany            0.398633        -0.005617       0.423809
# YearsInCurrentRole        0.301270        -0.003526       0.284636
# YearsSinceLastPromotion   0.281919        -0.040619       0.264921
# YearsWithCurrManager      0.291492        -0.033697       0.287713
#
#                           MonthlyRate  NumCompaniesWorked  PercentSalaryHike  \
# Age                          0.026194            0.242811           0.000531
# DailyRate                   -0.047495            0.067844           0.013789
# DistanceFromHome             0.012661           -0.005975           0.043854
# Education                   -0.013364            0.110197          -0.024706
# EmployeeCount               -0.058362            0.018780           0.001677
# EmployeeNumber               0.024262           -0.025675          -0.019600
# EnvironmentSatisfaction      0.017067           -0.010102          -0.004322
# HourlyRate                  -0.013290            0.033251          -0.023512
# JobInvolvement              -0.005866            0.003752          -0.026202
# JobLevel                     0.048162            0.122163          -0.040647
# JobSatisfaction             -0.022179           -0.050632           0.020191
# MonthlyIncome                0.038399            0.136470          -0.019717
# MonthlyRate                  1.000000            0.022777          -0.030876
# NumCompaniesWorked           0.022777            1.000000          -0.000136
# PercentSalaryHike           -0.030876           -0.000136           1.000000
# PerformanceRating           -0.050144            0.019406           0.352489
# RelationshipSatisfaction    -0.007363            0.043648          -0.010385
# StandardHours               -0.016434           -0.023836          -0.076547
# StockOptionLevel            -0.011956            0.029754          -0.025619
# TotalWorkingYears            0.022497            0.208482          -0.030281
# TrainingTimesLastYear       -0.000596           -0.069254          -0.003977
# WorkLifeBalance              0.011085           -0.031334          -0.014618
# YearsAtCompany              -0.012814           -0.092006          -0.024759
# YearsInCurrentRole           0.016271           -0.084804           0.000153
# YearsSinceLastPromotion      0.018762           -0.041212          -0.012282
# YearsWithCurrManager        -0.024287           -0.108499          -0.006729
#
#                           PerformanceRating  RelationshipSatisfaction  \
# Age                                0.007625                  0.016557
# DailyRate                          0.006227                  0.015816
# DistanceFromHome                  -0.018826                  0.016533
# Education                         -0.025934                 -0.028595
# EmployeeCount                     -0.039111                  0.013965
# EmployeeNumber                    -0.014001                 -0.057390
# EnvironmentSatisfaction            0.015540                  0.026868
# HourlyRate                        -0.012177                 -0.008126
# JobInvolvement                    -0.004608                  0.007647
# JobLevel                           0.003606                  0.027708
# JobSatisfaction                    0.027861                 -0.016042
# MonthlyIncome                      0.016438                  0.004406
# MonthlyRate                       -0.050144                 -0.007363
# NumCompaniesWorked                 0.019406                  0.043648
# PercentSalaryHike                  0.352489                 -0.010385
# PerformanceRating                  1.000000                 -0.023696
# RelationshipSatisfaction          -0.023696                  1.000000
# StandardHours                     -0.039057                  0.000202
# StockOptionLevel                   0.003460                 -0.063528
# TotalWorkingYears                  0.009699                  0.005926
# TrainingTimesLastYear              0.036989                  0.016842
# WorkLifeBalance                   -0.022503                  0.020219
# YearsAtCompany                    -0.007234                  0.003127
# YearsInCurrentRole                -0.025511                 -0.024074
# YearsSinceLastPromotion            0.008680                  0.028203
# YearsWithCurrManager              -0.011592                 -0.024814
#
#                           StandardHours  StockOptionLevel  TotalWorkingYears  \
# Age                            0.003184          0.022496           0.565104
# DailyRate                     -0.034749         -0.005738           0.013246
# DistanceFromHome              -0.004839          0.022948          -0.000803
# Education                     -0.001738          0.006493           0.121545
# EmployeeCount                  0.022519         -0.024769           0.000486
# EmployeeNumber                 0.000468          0.041849          -0.020649
# EnvironmentSatisfaction       -0.018678         -0.020219          -0.001120
# HourlyRate                    -0.013988          0.024828           0.045075
# JobInvolvement                -0.002444         -0.027089           0.021441
# JobLevel                       0.035952         -0.007489           0.635438
# JobSatisfaction                0.028780         -0.013806          -0.050177
# MonthlyIncome                  0.014685         -0.020070           0.681879
# MonthlyRate                   -0.016434         -0.011956           0.022497
# NumCompaniesWorked            -0.023836          0.029754           0.208482
# PercentSalaryHike             -0.076547         -0.025619          -0.030281
# PerformanceRating             -0.039057          0.003460           0.009699
# RelationshipSatisfaction       0.000202         -0.063528           0.005926
# StandardHours                  1.000000          0.011367           0.011514
# StockOptionLevel               0.011367          1.000000          -0.000411
# TotalWorkingYears              0.011514         -0.000411           1.000000
# TrainingTimesLastYear         -0.017867          0.046496          -0.055902
# WorkLifeBalance               -0.012482          0.053428           0.000845
# YearsAtCompany                -0.022240         -0.012162           0.524389
# YearsInCurrentRole             0.017459          0.014429           0.391886
# YearsSinceLastPromotion       -0.033208         -0.005880           0.359717
# YearsWithCurrManager           0.001469         -0.022296           0.398099
#
#                           TrainingTimesLastYear  WorkLifeBalance  \
# Age                                   -0.027055        -0.029410
# DailyRate                             -0.000828        -0.023298
# DistanceFromHome                      -0.028438        -0.004841
# Education                             -0.025671         0.012570
# EmployeeCount                         -0.038604        -0.014235
# EmployeeNumber                        -0.009689         0.004054
# EnvironmentSatisfaction               -0.018974         0.025012
# HourlyRate                            -0.018096        -0.002544
# JobInvolvement                        -0.011050        -0.005309
# JobLevel                              -0.028062         0.022846
# JobSatisfaction                        0.003432        -0.034414
# MonthlyIncome                         -0.044787         0.026940
# MonthlyRate                           -0.000596         0.011085
# NumCompaniesWorked                    -0.069254        -0.031334
# PercentSalaryHike                     -0.003977        -0.014618
# PerformanceRating                      0.036989        -0.022503
# RelationshipSatisfaction               0.016842         0.020219
# StandardHours                         -0.017867        -0.012482
# StockOptionLevel                       0.046496         0.053428
# TotalWorkingYears                     -0.055902         0.000845
# TrainingTimesLastYear                  1.000000        -0.009791
# WorkLifeBalance                       -0.009791         1.000000
# YearsAtCompany                        -0.019318         0.014893
# YearsInCurrentRole                    -0.014836         0.025277
# YearsSinceLastPromotion               -0.032485        -0.014488
# YearsWithCurrManager                  -0.017153        -0.010101
#
#                           YearsAtCompany  YearsInCurrentRole  \
# Age                             0.242254            0.151734
# DailyRate                      -0.034174            0.001199
# DistanceFromHome                0.017098            0.017368
# Education                       0.062105            0.069232
# EmployeeCount                   0.013620            0.010864
# EmployeeNumber                 -0.000139           -0.014226
# EnvironmentSatisfaction        -0.022402           -0.008779
# HourlyRate                      0.038194           -0.004516
# JobInvolvement                  0.001699            0.024746
# JobLevel                        0.398633            0.301270
# JobSatisfaction                -0.005617           -0.003526
# MonthlyIncome                   0.423809            0.284636
# MonthlyRate                    -0.012814            0.016271
# NumCompaniesWorked             -0.092006           -0.084804
# PercentSalaryHike              -0.024759            0.000153
# PerformanceRating              -0.007234           -0.025511
# RelationshipSatisfaction        0.003127           -0.024074
# StandardHours                  -0.022240            0.017459
# StockOptionLevel               -0.012162            0.014429
# TotalWorkingYears               0.524389            0.391886
# TrainingTimesLastYear          -0.019318           -0.014836
# WorkLifeBalance                 0.014893            0.025277
# YearsAtCompany                  1.000000            0.659566
# YearsInCurrentRole              0.659566            1.000000
# YearsSinceLastPromotion         0.555192            0.462719
# YearsWithCurrManager            0.668332            0.591921
#
#                           YearsSinceLastPromotion  YearsWithCurrManager
# Age                                      0.150223              0.160209
# DailyRate                               -0.032508             -0.049434
# DistanceFromHome                        -0.019859              0.036633
# Education                                0.040530              0.060829
# EmployeeCount                           -0.002832             -0.043815
# EmployeeNumber                          -0.009528             -0.021051
# EnvironmentSatisfaction                 -0.021576             -0.050086
# HourlyRate                               0.005587              0.017230
# JobInvolvement                           0.017100              0.037702
# JobLevel                                 0.281919              0.291492
# JobSatisfaction                         -0.040619             -0.033697
# MonthlyIncome                            0.264921              0.287713
# MonthlyRate                              0.018762             -0.024287
# NumCompaniesWorked                      -0.041212             -0.108499
# PercentSalaryHike                       -0.012282             -0.006729
# PerformanceRating                        0.008680             -0.011592
# RelationshipSatisfaction                 0.028203             -0.024814
# StandardHours                           -0.033208              0.001469
# StockOptionLevel                        -0.005880             -0.022296
# TotalWorkingYears                        0.359717              0.398099
# TrainingTimesLastYear                   -0.032485             -0.017153
# WorkLifeBalance                         -0.014488             -0.010101
# YearsAtCompany                           0.555192              0.668332
# YearsInCurrentRole                       0.462719              0.591921
# YearsSinceLastPromotion                  1.000000              0.423286
# YearsWithCurrManager                     0.423286              1.000000

# %% [markdown]
# ●2 Formulate and test hypotheses within a business context using appropriate statistical techniques
# like t-tests or ANOVA to identify significant relationships between variables. Provide a summary of
# your findings. Use at least two statistical tests. (0-40 marks)

# %%
from scipy import stats
stats.probplot(dataset.JobSatisfaction,plot=plt)
plt.figure()

# %% [markdown]
# ● 3 Use a Jupyter notebook to produce result sets from the provided dataset, such as scatter plots or
# regression models. Provide a summary of your findings. (0-10 marks)
#
# ● 4 Write the results of the analysis of your findings to stakeholders using clear and concise
# explanations, visualisations, and appropriate statistical terminology. (0-20 marks)
